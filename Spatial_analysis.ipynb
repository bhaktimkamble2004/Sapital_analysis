# %%
import ee

# %%
import geemap

# %%
ee.Authenticate()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ee.Initialize(project= "bhakti-ee")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
map = geemap.Map()
map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(childr…

# %%
Landsat5 = ee.ImageCollection("LANDSAT/LT05/C02/T1_TOA")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
TALUKA = ee.FeatureCollection("projects/bhakti-ee/assets/TALUKA_BOUNDARY")
Dapoli = TALUKA.filter(ee.Filter.eq("TALUKA","Dapoli"))
map.addLayer(TALUKA, {}, "ROI")
map.centerObject(TALUKA, 11)
map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[17.628954550408725, 73.42307354048903], controls=(WidgetControl(options=['position', 'transparent_…

# %%
Landsat5 = ee.ImageCollection("LANDSAT/LT05/C02/T1_TOA")
Land_5 = Landsat5.select('B1','B2','B3','B4','B5','B6','B7')
ROI_L5 = Land_5.filterBounds(TALUKA).filterDate("2001-01-01","2001-07-30").filterMetadata('CLOUD_COVER_LAND', 'less_than', 20).mean().clip(TALUKA)
#map.addLayer(TALUKA, {}, "ROI_L5")
#map.addLayer(ROI_L5,{},"ROI_L52001432")
#map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
NIR = ROI_L5.select("B4")
RED = ROI_L5.select("B3")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ROI_NDVI =  NIR.subtract(RED).divide(NIR.add(RED)).rename("NDVI")
vis_params = {'bands': ['NDVI'], 'palette': ['#f7fcf5', '#f6fcf4', '#f6fcf4', '#f5fbf3', '#f5fbf2', '#f4fbf2', '#f4fbf1', '#f3faf0', '#f2faf0', '#f2faef', '#f1faee', '#f1faee', '#f0f9ed', '#f0f9ec', '#eff9ec', '#eff9eb', '#eef8ea', '#edf8ea', '#edf8e9', '#ecf8e8', '#ecf8e8', '#ebf7e7', '#ebf7e7', '#eaf7e6', '#e9f7e5', '#e9f7e5', '#e8f6e4', '#e8f6e3', '#e7f6e3', '#e7f6e2', '#e6f5e1', '#e5f5e1', '#e5f5e0', '#e4f5df', '#e3f4de', '#e2f4dd', '#e1f3dc', '#e0f3db', '#dff3da', '#def2d9', '#ddf2d8', '#dcf2d7', '#dbf1d6', '#dbf1d5', '#daf0d4', '#d9f0d3', '#d8f0d2', '#d7efd1', '#d6efd0', '#d5efcf', '#d4eece', '#d3eecd', '#d2edcc', '#d1edcb', '#d0edca', '#cfecc9', '#ceecc8', '#cdecc7', '#ccebc6', '#cbebc5', '#cbeac4', '#caeac3', '#c9eac2', '#c8e9c1', '#c7e9c0', '#c6e8bf', '#c4e8bd', '#c3e7bc', '#c2e7bb', '#c1e6ba', '#c0e6b9', '#bee5b8', '#bde5b6', '#bce4b5', '#bbe4b4', '#bae3b3', '#b8e3b2', '#b7e2b1', '#b6e2af', '#b5e1ae', '#b4e1ad', '#b2e0ac', '#b1e0ab', '#b0dfaa', '#afdfa8', '#aedea7', '#acdea6', '#abdda5', '#aadda4', '#a9dca3', '#a8dca2', '#a7dba0', '#a5db9f', '#a4da9e', '#a3da9d', '#a2d99c', '#a0d99b', '#9fd899', '#9ed798', '#9cd797', '#9bd696', '#99d595', '#98d594', '#97d492', '#95d391', '#94d390', '#92d28f', '#91d28e', '#90d18d', '#8ed08b', '#8dd08a', '#8bcf89', '#8ace88', '#88ce87', '#87cd86', '#86cc85', '#84cc83', '#83cb82', '#81ca81', '#80ca80', '#7fc97f', '#7dc87e', '#7cc87c', '#7ac77b', '#79c67a', '#78c679', '#76c578', '#75c477', '#73c476', '#72c375', '#70c274', '#6ec173', '#6dc072', '#6bc072', '#6abf71', '#68be70', '#66bd6f', '#65bd6f', '#63bc6e', '#62bb6d', '#60ba6c', '#5eb96b', '#5db96b', '#5bb86a', '#5ab769', '#58b668', '#56b567', '#55b567', '#53b466', '#52b365', '#50b264', '#4eb264', '#4db163', '#4bb062', '#4aaf61', '#48ae60', '#46ae60', '#45ad5f', '#43ac5e', '#42ab5d', '#40aa5d', '#3fa95c', '#3fa85b', '#3ea75a', '#3da65a', '#3ca559', '#3ba458', '#3aa357', '#39a257', '#38a156', '#37a055', '#369f54', '#359e53', '#349d53', '#339c52', '#329b51', '#319a50', '#309950', '#2f984f', '#2f974e', '#2e964d', '#2d954d', '#2c944c', '#2b934b', '#2a924a', '#29914a', '#289049', '#278f48', '#268e47', '#258d47', '#248c46', '#238b45', '#228a44', '#218944', '#208843', '#1f8742', '#1e8741', '#1d8640', '#1c8540', '#1a843f', '#19833e', '#18823d', '#17813d', '#16803c', '#157f3b', '#147e3a', '#137d39', '#127c39', '#117b38', '#107a37', '#0e7936', '#0d7836', '#0c7735', '#0b7734', '#0a7633', '#097532', '#087432', '#077331', '#067230', '#05712f', '#03702e', '#026f2e', '#016e2d', '#006d2c', '#006c2c', '#006b2b', '#00692a', '#00682a', '#006729', '#006529', '#006428', '#006328', '#006227', '#006027', '#005f26', '#005e26', '#005c25', '#005b25', '#005a24', '#005924', '#005723', '#005622', '#005522', '#005321', '#005221', '#005120', '#005020', '#004e1f', '#004d1f', '#004c1e', '#004a1e', '#00491d', '#00481d', '#00471c', '#00451c', '#00441b'], 'min': -0.31392151003045027, 'max': 0.6756459338199442}
map.addLayer(ROI_NDVI, vis_params,"ROI_NDVI")
map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[17.628954550408725, 73.42307354048903], controls=(WidgetControl(options=['position', 'transparent_…

# %%
NDVI_Reclass = (ROI_NDVI
 .where(ROI_NDVI.lte(0.0), 1)  # Class 1: -0.3 to 0.0
 .where(ROI_NDVI.gt(0.0).And(ROI_NDVI.lte(0.35)), 2) # Class 2: 0.0 to 0.35
 .where(ROI_NDVI.gt(0.35), 3) # Class 3: 0.35 to 0.7
 .rename('NDVI_Classes')
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
vis_params = {'bands': ['NDVI_Classes'], 'palette': ['#f7fcf5', '#c7e9c0', '#74c476', '#238b45', '#00441b'], 'min': 1.0, 'max': 3.0}
#map.addLayer(NDVI_Reclass, vis_params, "NDVI_Reclass")
#map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
DEM = ee.Image("USGS/SRTMGL1_003").select("elevation")
ROI_DEM = DEM.clip(TALUKA)
DEM_palette = {'bands': ['elevation'], 'palette': ['#fff7ec', '#fff7eb', '#fff6ea', '#fff6e9', '#fff5e7', '#fff5e6', '#fff4e5', '#fff4e4', '#fff3e3', '#fff3e2', '#fff2e1', '#fff2e0', '#fff1de', '#fff1dd', '#fff0dc', '#fff0db', '#feefda', '#feefd9', '#feefd8', '#feeed7', '#feeed5', '#feedd4', '#feedd3', '#feecd2', '#feecd1', '#feebd0', '#feebcf', '#feeace', '#feeacc', '#fee9cb', '#fee9ca', '#fee8c9', '#fee8c8', '#fee7c7', '#fee7c5', '#fee6c4', '#fee5c3', '#fee5c1', '#fee4c0', '#fee4bf', '#fee3bd', '#fee2bc', '#fee2bb', '#fee1b9', '#fee0b8', '#fee0b7', '#fedfb5', '#fedfb4', '#fddeb3', '#fdddb1', '#fdddb0', '#fddcaf', '#fddbad', '#fddbac', '#fddaab', '#fdd9aa', '#fdd9a8', '#fdd8a7', '#fdd8a6', '#fdd7a4', '#fdd6a3', '#fdd6a2', '#fdd5a0', '#fdd49f', '#fdd49e', '#fdd39d', '#fdd29c', '#fdd19b', '#fdd19b', '#fdd09a', '#fdcf99', '#fdce98', '#fdce97', '#fdcd96', '#fdcc96', '#fdcb95', '#fdca94', '#fdca93', '#fdc992', '#fdc892', '#fdc791', '#fdc690', '#fdc68f', '#fdc58e', '#fdc48d', '#fdc38d', '#fdc38c', '#fdc28b', '#fdc18a', '#fdc089', '#fdbf89', '#fdbf88', '#fdbe87', '#fdbd86', '#fdbc85', '#fdbb85', '#fdba83', '#fdb982', '#fdb881', '#fdb67f', '#fdb57e', '#fdb37d', '#fdb27b', '#fdb07a', '#fdaf79', '#fdad77', '#fdac76', '#fdab75', '#fda973', '#fda872', '#fda671', '#fda56f', '#fca36e', '#fca26d', '#fca06b', '#fc9f6a', '#fc9e69', '#fc9c67', '#fc9b66', '#fc9964', '#fc9863', '#fc9662', '#fc9560', '#fc935f', '#fc925e', '#fc915c', '#fc8f5b', '#fc8e5a', '#fc8c59', '#fb8b58', '#fb8a58', '#fb8957', '#fa8757', '#fa8656', '#f98556', '#f98455', '#f98254', '#f88154', '#f88053', '#f77f53', '#f77d52', '#f67c52', '#f67b51', '#f67a51', '#f57850', '#f57750', '#f4764f', '#f4754f', '#f4734e', '#f3724e', '#f3714d', '#f2704c', '#f26e4c', '#f26d4b', '#f16c4b', '#f16a4a', '#f0694a', '#f06849', '#f06749', '#ef6548', '#ef6447', '#ee6246', '#ed6145', '#ec5f43', '#ec5d42', '#eb5c41', '#ea5a3f', '#e9583e', '#e9573d', '#e8553c', '#e7533a', '#e65239', '#e55038', '#e54e36', '#e44d35', '#e34b34', '#e24933', '#e24831', '#e14630', '#e0442f', '#df432d', '#df412c', '#de3f2b', '#dd3e2a', '#dc3c28', '#dc3a27', '#db3926', '#da3724', '#d93523', '#d93422', '#d83221', '#d7301f', '#d62f1e', '#d52d1d', '#d42c1c', '#d32a1b', '#d2291a', '#d12719', '#cf2618', '#ce2417', '#cd2316', '#cc2116', '#cb2015', '#ca1e14', '#c91d13', '#c71b12', '#c61a11', '#c51810', '#c4170f', '#c3150e', '#c2140d', '#c1120c', '#c0110b', '#be0f0a', '#bd0e09', '#bc0c08', '#bb0b07', '#ba0906', '#b90805', '#b80604', '#b70503', '#b50302', '#b40201', '#b30000', '#b20000', '#b00000', '#ae0000', '#ad0000', '#ab0000', '#a90000', '#a80000', '#a60000', '#a50000', '#a30000', '#a10000', '#a00000', '#9e0000', '#9c0000', '#9b0000', '#990000', '#970000', '#960000', '#940000', '#930000', '#910000', '#8f0000', '#8e0000', '#8c0000', '#8a0000', '#890000', '#870000', '#860000', '#840000', '#820000', '#810000', '#7f0000'], 'min': 206.0, 'max': 247.0}
#map.addLayer(ROI_DEM, DEM_palette, "ROI_DEM")
#map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
NIR = ROI_L5.select("B4")
RED = ROI_L5.select("B3")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ROI_SAVI = (NIR.subtract(RED).divide(NIR.add(NIR).multiply(0.5))).multiply(1.5)
vis_params = {'bands': ['B4'], 'palette': ['#a50026', '#a70226', '#a90426', '#ab0626', '#ad0826', '#af0926', '#b10b26', '#b30d26', '#b50f26', '#b71126', '#b91326', '#bb1526', '#bd1726', '#be1827', '#c01a27', '#c21c27', '#c41e27', '#c62027', '#c82227', '#ca2427', '#cc2627', '#ce2827', '#d02927', '#d22b27', '#d42d27', '#d62f27', '#d83128', '#d93429', '#da362a', '#db382b', '#dc3b2c', '#dd3d2d', '#de402e', '#e0422f', '#e14430', '#e24731', '#e34933', '#e44c34', '#e54e35', '#e65036', '#e75337', '#e95538', '#ea5739', '#eb5a3a', '#ec5c3b', '#ed5f3c', '#ee613e', '#ef633f', '#f16640', '#f26841', '#f36b42', '#f46d43', '#f47044', '#f57245', '#f57547', '#f57748', '#f67a49', '#f67c4a', '#f67f4b', '#f7814c', '#f7844e', '#f8864f', '#f88950', '#f88c51', '#f98e52', '#f99153', '#f99355', '#fa9656', '#fa9857', '#fa9b58', '#fb9d59', '#fba05b', '#fba35c', '#fca55d', '#fca85e', '#fcaa5f', '#fdad60', '#fdaf62', '#fdb163', '#fdb365', '#fdb567', '#fdb768', '#fdb96a', '#fdbb6c', '#fdbd6d', '#fdbf6f', '#fdc171', '#fdc372', '#fdc574', '#fdc776', '#fec877', '#feca79', '#fecc7b', '#fece7c', '#fed07e', '#fed27f', '#fed481', '#fed683', '#fed884', '#feda86', '#fedc88', '#fede89', '#fee08b', '#fee18d', '#fee28f', '#fee491', '#fee593', '#fee695', '#fee797', '#fee999', '#feea9b', '#feeb9d', '#feec9f', '#feeda1', '#feefa3', '#fff0a6', '#fff1a8', '#fff2aa', '#fff3ac', '#fff5ae', '#fff6b0', '#fff7b2', '#fff8b4', '#fffab6', '#fffbb8', '#fffcba', '#fffdbc', '#fffebe', '#feffbe', '#fdfebc', '#fbfdba', '#fafdb8', '#f8fcb6', '#f7fcb4', '#f5fbb2', '#f4fab0', '#f2faae', '#f1f9ac', '#eff8aa', '#eef8a8', '#ecf7a6', '#ebf7a3', '#e9f6a1', '#e8f59f', '#e6f59d', '#e5f49b', '#e3f399', '#e2f397', '#e0f295', '#dff293', '#ddf191', '#dcf08f', '#daf08d', '#d9ef8b', '#d7ee8a', '#d5ed88', '#d3ec87', '#d1ec86', '#cfeb85', '#cdea83', '#cbe982', '#c9e881', '#c7e77f', '#c5e67e', '#c3e67d', '#c1e57b', '#bfe47a', '#bde379', '#bbe278', '#b9e176', '#b7e075', '#b5df74', '#b3df72', '#b1de71', '#afdd70', '#addc6f', '#abdb6d', '#a9da6c', '#a7d96b', '#a5d86a', '#a2d76a', '#a0d669', '#9dd569', '#9bd469', '#98d368', '#96d268', '#93d168', '#91d068', '#8ecf67', '#8ccd67', '#89cc67', '#87cb67', '#84ca66', '#82c966', '#7fc866', '#7dc765', '#7ac665', '#78c565', '#75c465', '#73c264', '#70c164', '#6ec064', '#6bbf64', '#69be63', '#66bd63', '#63bc62', '#60ba62', '#5db961', '#5ab760', '#57b65f', '#54b45f', '#51b35e', '#4eb15d', '#4bb05c', '#48ae5c', '#45ad5b', '#42ac5a', '#3faa59', '#3ca959', '#39a758', '#36a657', '#33a456', '#30a356', '#2da155', '#2aa054', '#279f53', '#249d53', '#219c52', '#1e9a51', '#1b9950', '#199750', '#18954f', '#17934e', '#16914d', '#15904c', '#148e4b', '#138c4a', '#128a49', '#118848', '#108647', '#0f8446', '#0e8245', '#0d8044', '#0c7f43', '#0b7d42', '#0a7b41', '#097940', '#08773f', '#07753e', '#06733d', '#05713c', '#04703b', '#036e3a', '#026c39', '#016a38', '#006837'], 'min': -1.3793411709745746, 'max': 1.2018529803999156}
#map.addLayer(ROI_SAVI, vis_params,"ROI_SAVI")
#map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
GREEN = ROI_L5.select("B2")
ROI_NDWI = GREEN.subtract(NIR).divide(GREEN.add(NIR)).rename("NDWI")
vis_params = {'bands': ['NDWI'], 'palette': ['#f7fbff', '#f6faff', '#f5fafe', '#f5f9fe', '#f4f9fe', '#f3f8fe', '#f2f8fd', '#f2f7fd', '#f1f7fd', '#f0f6fd', '#eff6fc', '#eef5fc', '#eef5fc', '#edf4fc', '#ecf4fb', '#ebf3fb', '#eaf3fb', '#eaf2fb', '#e9f2fa', '#e8f1fa', '#e7f1fa', '#e7f0fa', '#e6f0f9', '#e5eff9', '#e4eff9', '#e3eef9', '#e3eef8', '#e2edf8', '#e1edf8', '#e0ecf8', '#dfecf7', '#dfebf7', '#deebf7', '#ddeaf7', '#dceaf6', '#dce9f6', '#dbe9f6', '#dae8f6', '#d9e8f5', '#d9e7f5', '#d8e7f5', '#d7e6f5', '#d6e6f4', '#d6e5f4', '#d5e5f4', '#d4e4f4', '#d3e4f3', '#d3e3f3', '#d2e3f3', '#d1e2f3', '#d0e2f2', '#d0e1f2', '#cfe1f2', '#cee0f2', '#cde0f1', '#cddff1', '#ccdff1', '#cbdef1', '#cadef0', '#caddf0', '#c9ddf0', '#c8dcf0', '#c7dcef', '#c7dbef', '#c6dbef', '#c4daee', '#c3daee', '#c2d9ee', '#c1d9ed', '#bfd8ed', '#bed8ec', '#bdd7ec', '#bcd7eb', '#bad6eb', '#b9d6ea', '#b8d5ea', '#b7d4ea', '#b5d4e9', '#b4d3e9', '#b3d3e8', '#b2d2e8', '#b0d2e7', '#afd1e7', '#aed1e7', '#add0e6', '#abd0e6', '#aacfe5', '#a9cfe5', '#a8cee4', '#a6cee4', '#a5cde3', '#a4cce3', '#a3cce3', '#a1cbe2', '#a0cbe2', '#9fcae1', '#9dcae1', '#9cc9e1', '#9ac8e0', '#99c7e0', '#97c6df', '#95c5df', '#94c4df', '#92c4de', '#91c3de', '#8fc2de', '#8dc1dd', '#8cc0dd', '#8abfdd', '#89bedc', '#87bddc', '#85bcdc', '#84bcdb', '#82bbdb', '#81badb', '#7fb9da', '#7db8da', '#7cb7da', '#7ab6d9', '#79b5d9', '#77b5d9', '#75b4d8', '#74b3d8', '#72b2d8', '#71b1d7', '#6fb0d7', '#6dafd7', '#6caed6', '#6aaed6', '#69add5', '#68acd5', '#66abd4', '#65aad4', '#64a9d3', '#63a8d3', '#61a7d2', '#60a7d2', '#5fa6d1', '#5da5d1', '#5ca4d0', '#5ba3d0', '#5aa2cf', '#58a1cf', '#57a0ce', '#56a0ce', '#549fcd', '#539ecd', '#529dcc', '#519ccc', '#4f9bcb', '#4e9acb', '#4d99ca', '#4b98ca', '#4a98c9', '#4997c9', '#4896c8', '#4695c8', '#4594c7', '#4493c7', '#4292c6', '#4191c6', '#4090c5', '#3f8fc5', '#3e8ec4', '#3d8dc4', '#3c8cc3', '#3b8bc2', '#3a8ac2', '#3989c1', '#3888c1', '#3787c0', '#3686c0', '#3585bf', '#3484bf', '#3383be', '#3282be', '#3181bd', '#3080bd', '#2f7fbc', '#2e7ebc', '#2d7dbb', '#2c7cba', '#2b7bba', '#2a7ab9', '#2979b9', '#2777b8', '#2676b8', '#2575b7', '#2474b7', '#2373b6', '#2272b6', '#2171b5', '#2070b4', '#206fb4', '#1f6eb3', '#1e6db2', '#1d6cb1', '#1c6bb0', '#1c6ab0', '#1b69af', '#1a68ae', '#1967ad', '#1966ad', '#1865ac', '#1764ab', '#1663aa', '#1562a9', '#1561a9', '#1460a8', '#135fa7', '#125ea6', '#125da6', '#115ca5', '#105ba4', '#0f5aa3', '#0e59a2', '#0e58a2', '#0d57a1', '#0c56a0', '#0b559f', '#0a549e', '#0a539e', '#09529d', '#08519c', '#08509b', '#084f99', '#084e98', '#084d96', '#084c95', '#084b93', '#084a91', '#084990', '#08488e', '#08478d', '#08468b', '#08458a', '#084488', '#084387', '#084285', '#084184', '#084082', '#083e81', '#083d7f', '#083c7d', '#083b7c', '#083a7a', '#083979', '#083877', '#083776', '#083674', '#083573', '#083471', '#083370', '#08326e', '#08316d', '#08306b'], 'min': -0.5623302686286402, 'max': 0.4410759883438791}
#map.addLayer(ROI_NDWI,vis_params,"ROI_NDWI")
#map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
SWIR = ROI_L5.select("B5")
ROI_NDMI = NIR.subtract(SWIR).divide(NIR.add(SWIR)).rename("NDMI")
vis_params = {'bands': ['NDMI'], 'palette': ['#f7fcfd', '#e6f0f6', '#d1e1ee', '#b9cfe4', '#a1bedb', '#93a4cd', '#8c86be', '#8c67af', '#8949a1', '#84268b', '#730b6f', '#4d004b'], 'min': -0.23403907984321531, 'max': 0.5011594138231518}
#map.addLayer(ROI_NDMI,vis_params,"ROI_NDMI")
#map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ROI_NDBI = SWIR.subtract(NIR).divide(SWIR.add(NIR)).rename("NDBI")
vis_params = {'bands': ['NDBI'], 'palette': ['#a50026', '#a70226', '#a90426', '#ab0626', '#ad0826', '#af0926', '#b10b26', '#b30d26', '#b50f26', '#b71126', '#b91326', '#bb1526', '#bd1726', '#be1827', '#c01a27', '#c21c27', '#c41e27', '#c62027', '#c82227', '#ca2427', '#cc2627', '#ce2827', '#d02927', '#d22b27', '#d42d27', '#d62f27', '#d83128', '#d93429', '#da362a', '#db382b', '#dc3b2c', '#dd3d2d', '#de402e', '#e0422f', '#e14430', '#e24731', '#e34933', '#e44c34', '#e54e35', '#e65036', '#e75337', '#e95538', '#ea5739', '#eb5a3a', '#ec5c3b', '#ed5f3c', '#ee613e', '#ef633f', '#f16640', '#f26841', '#f36b42', '#f46d43', '#f47044', '#f57245', '#f57547', '#f57748', '#f67a49', '#f67c4a', '#f67f4b', '#f7814c', '#f7844e', '#f8864f', '#f88950', '#f88c51', '#f98e52', '#f99153', '#f99355', '#fa9656', '#fa9857', '#fa9b58', '#fb9d59', '#fba05b', '#fba35c', '#fca55d', '#fca85e', '#fcaa5f', '#fdad60', '#fdaf62', '#fdb163', '#fdb365', '#fdb567', '#fdb768', '#fdb96a', '#fdbb6c', '#fdbd6d', '#fdbf6f', '#fdc171', '#fdc372', '#fdc574', '#fdc776', '#fec877', '#feca79', '#fecc7b', '#fece7c', '#fed07e', '#fed27f', '#fed481', '#fed683', '#fed884', '#feda86', '#fedc88', '#fede89', '#fee08b', '#fee18d', '#fee28f', '#fee491', '#fee593', '#fee695', '#fee797', '#fee999', '#feea9b', '#feeb9d', '#feec9f', '#feeda1', '#feefa3', '#fff0a6', '#fff1a8', '#fff2aa', '#fff3ac', '#fff5ae', '#fff6b0', '#fff7b2', '#fff8b4', '#fffab6', '#fffbb8', '#fffcba', '#fffdbc', '#fffebe', '#feffbe', '#fdfebc', '#fbfdba', '#fafdb8', '#f8fcb6', '#f7fcb4', '#f5fbb2', '#f4fab0', '#f2faae', '#f1f9ac', '#eff8aa', '#eef8a8', '#ecf7a6', '#ebf7a3', '#e9f6a1', '#e8f59f', '#e6f59d', '#e5f49b', '#e3f399', '#e2f397', '#e0f295', '#dff293', '#ddf191', '#dcf08f', '#daf08d', '#d9ef8b', '#d7ee8a', '#d5ed88', '#d3ec87', '#d1ec86', '#cfeb85', '#cdea83', '#cbe982', '#c9e881', '#c7e77f', '#c5e67e', '#c3e67d', '#c1e57b', '#bfe47a', '#bde379', '#bbe278', '#b9e176', '#b7e075', '#b5df74', '#b3df72', '#b1de71', '#afdd70', '#addc6f', '#abdb6d', '#a9da6c', '#a7d96b', '#a5d86a', '#a2d76a', '#a0d669', '#9dd569', '#9bd469', '#98d368', '#96d268', '#93d168', '#91d068', '#8ecf67', '#8ccd67', '#89cc67', '#87cb67', '#84ca66', '#82c966', '#7fc866', '#7dc765', '#7ac665', '#78c565', '#75c465', '#73c264', '#70c164', '#6ec064', '#6bbf64', '#69be63', '#66bd63', '#63bc62', '#60ba62', '#5db961', '#5ab760', '#57b65f', '#54b45f', '#51b35e', '#4eb15d', '#4bb05c', '#48ae5c', '#45ad5b', '#42ac5a', '#3faa59', '#3ca959', '#39a758', '#36a657', '#33a456', '#30a356', '#2da155', '#2aa054', '#279f53', '#249d53', '#219c52', '#1e9a51', '#1b9950', '#199750', '#18954f', '#17934e', '#16914d', '#15904c', '#148e4b', '#138c4a', '#128a49', '#118848', '#108647', '#0f8446', '#0e8245', '#0d8044', '#0c7f43', '#0b7d42', '#0a7b41', '#097940', '#08773f', '#07753e', '#06733d', '#05713c', '#04703b', '#036e3a', '#026c39', '#016a38', '#006837'], 'min': -0.23403907984321531, 'max': 0.5011594138231518}
#map.addLayer(ROI_NDBI,vis_params,"ROI_NDBI")
#map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
DEM_ft = DEM.multiply(3.28)
vis_params = {'bands': ['elevation'], 'palette': ['#313695', '#5183bb', '#90c3dd', '#d3ecf4', '#ffffbf', '#fed384', '#f98e52', '#de3f2e', '#a50026'], 'min': 0.0, 'max': 1013.0}
#map.addLayer(ROI_DEM, vis_params, "DEM_ft")
#map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
DEM = ee.Image("USGS/SRTMGL1_003").select("elevation")
ROI_DEM = DEM.clip(TALUKA)
DEM_palette = {'bands': ['elevation'], 'palette': ['#fff7ec', '#fff7eb', '#fff6ea', '#fff6e9', '#fff5e7', '#fff5e6', '#fff4e5', '#fff4e4', '#fff3e3', '#fff3e2', '#fff2e1', '#fff2e0', '#fff1de', '#fff1dd', '#fff0dc', '#fff0db', '#feefda', '#feefd9', '#feefd8', '#feeed7', '#feeed5', '#feedd4', '#feedd3', '#feecd2', '#feecd1', '#feebd0', '#feebcf', '#feeace', '#feeacc', '#fee9cb', '#fee9ca', '#fee8c9', '#fee8c8', '#fee7c7', '#fee7c5', '#fee6c4', '#fee5c3', '#fee5c1', '#fee4c0', '#fee4bf', '#fee3bd', '#fee2bc', '#fee2bb', '#fee1b9', '#fee0b8', '#fee0b7', '#fedfb5', '#fedfb4', '#fddeb3', '#fdddb1', '#fdddb0', '#fddcaf', '#fddbad', '#fddbac', '#fddaab', '#fdd9aa', '#fdd9a8', '#fdd8a7', '#fdd8a6', '#fdd7a4', '#fdd6a3', '#fdd6a2', '#fdd5a0', '#fdd49f', '#fdd49e', '#fdd39d', '#fdd29c', '#fdd19b', '#fdd19b', '#fdd09a', '#fdcf99', '#fdce98', '#fdce97', '#fdcd96', '#fdcc96', '#fdcb95', '#fdca94', '#fdca93', '#fdc992', '#fdc892', '#fdc791', '#fdc690', '#fdc68f', '#fdc58e', '#fdc48d', '#fdc38d', '#fdc38c', '#fdc28b', '#fdc18a', '#fdc089', '#fdbf89', '#fdbf88', '#fdbe87', '#fdbd86', '#fdbc85', '#fdbb85', '#fdba83', '#fdb982', '#fdb881', '#fdb67f', '#fdb57e', '#fdb37d', '#fdb27b', '#fdb07a', '#fdaf79', '#fdad77', '#fdac76', '#fdab75', '#fda973', '#fda872', '#fda671', '#fda56f', '#fca36e', '#fca26d', '#fca06b', '#fc9f6a', '#fc9e69', '#fc9c67', '#fc9b66', '#fc9964', '#fc9863', '#fc9662', '#fc9560', '#fc935f', '#fc925e', '#fc915c', '#fc8f5b', '#fc8e5a', '#fc8c59', '#fb8b58', '#fb8a58', '#fb8957', '#fa8757', '#fa8656', '#f98556', '#f98455', '#f98254', '#f88154', '#f88053', '#f77f53', '#f77d52', '#f67c52', '#f67b51', '#f67a51', '#f57850', '#f57750', '#f4764f', '#f4754f', '#f4734e', '#f3724e', '#f3714d', '#f2704c', '#f26e4c', '#f26d4b', '#f16c4b', '#f16a4a', '#f0694a', '#f06849', '#f06749', '#ef6548', '#ef6447', '#ee6246', '#ed6145', '#ec5f43', '#ec5d42', '#eb5c41', '#ea5a3f', '#e9583e', '#e9573d', '#e8553c', '#e7533a', '#e65239', '#e55038', '#e54e36', '#e44d35', '#e34b34', '#e24933', '#e24831', '#e14630', '#e0442f', '#df432d', '#df412c', '#de3f2b', '#dd3e2a', '#dc3c28', '#dc3a27', '#db3926', '#da3724', '#d93523', '#d93422', '#d83221', '#d7301f', '#d62f1e', '#d52d1d', '#d42c1c', '#d32a1b', '#d2291a', '#d12719', '#cf2618', '#ce2417', '#cd2316', '#cc2116', '#cb2015', '#ca1e14', '#c91d13', '#c71b12', '#c61a11', '#c51810', '#c4170f', '#c3150e', '#c2140d', '#c1120c', '#c0110b', '#be0f0a', '#bd0e09', '#bc0c08', '#bb0b07', '#ba0906', '#b90805', '#b80604', '#b70503', '#b50302', '#b40201', '#b30000', '#b20000', '#b00000', '#ae0000', '#ad0000', '#ab0000', '#a90000', '#a80000', '#a60000', '#a50000', '#a30000', '#a10000', '#a00000', '#9e0000', '#9c0000', '#9b0000', '#990000', '#970000', '#960000', '#940000', '#930000', '#910000', '#8f0000', '#8e0000', '#8c0000', '#8a0000', '#890000', '#870000', '#860000', '#840000', '#820000', '#810000', '#7f0000'], 'min': 206.0, 'max': 247.0}
#map.addLayer(ROI_DEM, DEM_palette, "ROI_DEM")
#map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
DEM_Reclass = (ROI_DEM
 .where(ROI_DEM.gte(26),1)
 .where(ROI_DEM.gte(27).And(DEM.lt(59)),2)
 .where(ROI_DEM.gte(59).And(DEM.lt(103)),3)
 .where(ROI_DEM.gte(104).And(DEM.lt(153)),4)
 .where(ROI_DEM.gte(153),5)
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
vis_params = {'bands': ['elevation'], 'palette': ['#313695', '#323896', '#333b97', '#333d99', '#34409a', '#35429b', '#36459c', '#36479e', '#374a9f', '#384ca0', '#394fa1', '#3a51a2', '#3a54a4', '#3b56a5', '#3c59a6', '#3d5ba7', '#3e5ea8', '#3e60aa', '#3f62ab', '#4065ac', '#4167ad', '#416aaf', '#426cb0', '#436fb1', '#4471b2', '#4574b3', '#4676b5', '#4878b6', '#4a7ab7', '#4b7db8', '#4d7fb9', '#4f81ba', '#5183bb', '#5385bd', '#5588be', '#578abf', '#588cc0', '#5a8ec1', '#5c90c2', '#5e93c3', '#6095c4', '#6297c6', '#6399c7', '#659bc8', '#679ec9', '#69a0ca', '#6ba2cb', '#6da4cc', '#6ea6ce', '#70a9cf', '#72abd0', '#74add1', '#76afd2', '#78b0d3', '#7ab2d4', '#7db4d5', '#7fb6d6', '#81b7d7', '#83b9d8', '#85bbd9', '#87bdd9', '#8abeda', '#8cc0db', '#8ec2dc', '#90c3dd', '#92c5de', '#94c7df', '#97c9e0', '#99cae1', '#9bcce2', '#9dcee3', '#9fd0e4', '#a1d1e5', '#a3d3e6', '#a6d5e7', '#a8d6e8', '#aad8e9', '#acdae9', '#aedbea', '#b0dcea', '#b2ddeb', '#b4deec', '#b6dfec', '#b9e0ed', '#bbe1ed', '#bde2ee', '#bfe3ef', '#c1e4ef', '#c3e5f0', '#c5e6f0', '#c7e7f1', '#c9e8f2', '#cbe9f2', '#cdeaf3', '#cfebf3', '#d1ecf4', '#d4edf4', '#d6eef5', '#d8eff6', '#daf0f6', '#dcf1f7', '#def2f7', '#e0f3f8', '#e1f3f6', '#e2f4f4', '#e4f4f1', '#e5f5ef', '#e6f5ed', '#e7f6eb', '#e9f6e8', '#eaf7e6', '#ebf7e4', '#ecf8e2', '#edf8df', '#eff9dd', '#f0f9db', '#f1fad9', '#f2fad6', '#f3fbd4', '#f5fbd2', '#f6fbd0', '#f7fcce', '#f8fccb', '#fafdc9', '#fbfdc7', '#fcfec5', '#fdfec2', '#feffc0', '#fffebe', '#fffdbc', '#fffcba', '#fffbb9', '#fffab7', '#fff8b5', '#fff7b3', '#fff6b1', '#fff5af', '#fff3ad', '#fff2ac', '#fff1aa', '#fff0a8', '#feefa6', '#feeda4', '#feeca2', '#feeba1', '#feea9f', '#fee99d', '#fee79b', '#fee699', '#fee597', '#fee496', '#fee294', '#fee192', '#fee090', '#fede8e', '#fedc8c', '#feda8a', '#fed889', '#fed687', '#fed485', '#fed283', '#fed081', '#fece7f', '#fecc7e', '#feca7c', '#fec87a', '#fdc778', '#fdc576', '#fdc374', '#fdc173', '#fdbf71', '#fdbd6f', '#fdbb6d', '#fdb96b', '#fdb769', '#fdb567', '#fdb366', '#fdb164', '#fdaf62', '#fdad60', '#fcaa5f', '#fca85e', '#fca55d', '#fba35c', '#fba05b', '#fb9d59', '#fa9b58', '#fa9857', '#fa9656', '#f99355', '#f99153', '#f98e52', '#f88c51', '#f88950', '#f8864f', '#f7844e', '#f7814c', '#f67f4b', '#f67c4a', '#f67a49', '#f57748', '#f57547', '#f57245', '#f47044', '#f46d43', '#f36b42', '#f26841', '#f16640', '#ef633f', '#ee613e', '#ed5f3c', '#ec5c3b', '#eb5a3a', '#ea5739', '#e95538', '#e75337', '#e65036', '#e54e35', '#e44c34', '#e34933', '#e24731', '#e14430', '#e0422f', '#de402e', '#dd3d2d', '#dc3b2c', '#db382b', '#da362a', '#d93429', '#d83128', '#d62f27', '#d42d27', '#d22b27', '#d02927', '#ce2827', '#cc2627', '#ca2427', '#c82227', '#c62027', '#c41e27', '#c21c27', '#c01a27', '#be1827', '#bd1726', '#bb1526', '#b91326', '#b71126', '#b50f26', '#b30d26', '#b10b26', '#af0926', '#ad0826', '#ab0626', '#a90426', '#a70226', '#a50026'], 'min': 0.0, 'max': 25.0}
#map.addLayer(DEM_Reclass,vis_params, "DEM_Reclass")
#map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
terrain = ee.Terrain.products(ROI_DEM)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
slope = terrain.select('slope')
aspect = terrain.select('aspect')
hillshade = terrain.select('hillshade')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
slope_vis = {'min': 0, 'max': 60, 'palette': ['white', 'yellow', 'orange', 'red']}
aspect_vis = {'min': 0, 'max': 360, 'palette': ['blue', 'cyan', 'green', 'yellow', 'red']}
hillshade_vis = {'min': 0, 'max': 255}
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
map.addLayer(slope,slope_vis,"slope")
map.addLayer(aspect,aspect_vis,"aspect")
map.addLayer(hillshade,{},"hillshade")
map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(bottom=236355.0, center=[17.628954550408725, 73.42307354048903], controls=(WidgetControl(options=['positio…

# %%
LANDSAT9 = ee.ImageCollection("LANDSAT/LC09/C02/T1_TOA")
L9_TCC = LANDSAT9.select('B4','B3','B2')
L9_FCC = LANDSAT9.select('B5', 'B4', 'B3')
ROIL9_TCC = L9_TCC.filterBounds(TALUKA).filterDate("2025-02-01","2025-06-15").filterMetadata('CLOUD_COVER', 'less_than', 20).mean().clip(TALUKA)
ROIL9_FCC = L9_FCC.filterBounds(TALUKA).filterDate("2025-02-01","2025-06-15").filterMetadata('CLOUD_COVER', 'less_than', 20).mean().clip(TALUKA)
map.addLayer(ROIL9_TCC, {}, "ROIL9_TCC")
map.addLayer(ROIL9_FCC, {}, "ROIL9_FCC")
map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(bottom=236355.0, center=[17.628954550408725, 73.42307354048903], controls=(WidgetControl(options=['positio…

# %%
ROI_NDVI2 = ROIL9_TCC.select("B4")
ROI_NDVI2 = ROIL9_TCC.select("B3")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ROI_NDVI2 =  NIR.subtract(RED).divide(NIR.add(RED)).rename("NDVI")
vis_params = {'bands': ['NDVI'], 'palette': ['#f7fcf5', '#f6fcf4', '#f6fcf4', '#f5fbf3', '#f5fbf2', '#f4fbf2', '#f4fbf1', '#f3faf0', '#f2faf0', '#f2faef', '#f1faee', '#f1faee', '#f0f9ed', '#f0f9ec', '#eff9ec', '#eff9eb', '#eef8ea', '#edf8ea', '#edf8e9', '#ecf8e8', '#ecf8e8', '#ebf7e7', '#ebf7e7', '#eaf7e6', '#e9f7e5', '#e9f7e5', '#e8f6e4', '#e8f6e3', '#e7f6e3', '#e7f6e2', '#e6f5e1', '#e5f5e1', '#e5f5e0', '#e4f5df', '#e3f4de', '#e2f4dd', '#e1f3dc', '#e0f3db', '#dff3da', '#def2d9', '#ddf2d8', '#dcf2d7', '#dbf1d6', '#dbf1d5', '#daf0d4', '#d9f0d3', '#d8f0d2', '#d7efd1', '#d6efd0', '#d5efcf', '#d4eece', '#d3eecd', '#d2edcc', '#d1edcb', '#d0edca', '#cfecc9', '#ceecc8', '#cdecc7', '#ccebc6', '#cbebc5', '#cbeac4', '#caeac3', '#c9eac2', '#c8e9c1', '#c7e9c0', '#c6e8bf', '#c4e8bd', '#c3e7bc', '#c2e7bb', '#c1e6ba', '#c0e6b9', '#bee5b8', '#bde5b6', '#bce4b5', '#bbe4b4', '#bae3b3', '#b8e3b2', '#b7e2b1', '#b6e2af', '#b5e1ae', '#b4e1ad', '#b2e0ac', '#b1e0ab', '#b0dfaa', '#afdfa8', '#aedea7', '#acdea6', '#abdda5', '#aadda4', '#a9dca3', '#a8dca2', '#a7dba0', '#a5db9f', '#a4da9e', '#a3da9d', '#a2d99c', '#a0d99b', '#9fd899', '#9ed798', '#9cd797', '#9bd696', '#99d595', '#98d594', '#97d492', '#95d391', '#94d390', '#92d28f', '#91d28e', '#90d18d', '#8ed08b', '#8dd08a', '#8bcf89', '#8ace88', '#88ce87', '#87cd86', '#86cc85', '#84cc83', '#83cb82', '#81ca81', '#80ca80', '#7fc97f', '#7dc87e', '#7cc87c', '#7ac77b', '#79c67a', '#78c679', '#76c578', '#75c477', '#73c476', '#72c375', '#70c274', '#6ec173', '#6dc072', '#6bc072', '#6abf71', '#68be70', '#66bd6f', '#65bd6f', '#63bc6e', '#62bb6d', '#60ba6c', '#5eb96b', '#5db96b', '#5bb86a', '#5ab769', '#58b668', '#56b567', '#55b567', '#53b466', '#52b365', '#50b264', '#4eb264', '#4db163', '#4bb062', '#4aaf61', '#48ae60', '#46ae60', '#45ad5f', '#43ac5e', '#42ab5d', '#40aa5d', '#3fa95c', '#3fa85b', '#3ea75a', '#3da65a', '#3ca559', '#3ba458', '#3aa357', '#39a257', '#38a156', '#37a055', '#369f54', '#359e53', '#349d53', '#339c52', '#329b51', '#319a50', '#309950', '#2f984f', '#2f974e', '#2e964d', '#2d954d', '#2c944c', '#2b934b', '#2a924a', '#29914a', '#289049', '#278f48', '#268e47', '#258d47', '#248c46', '#238b45', '#228a44', '#218944', '#208843', '#1f8742', '#1e8741', '#1d8640', '#1c8540', '#1a843f', '#19833e', '#18823d', '#17813d', '#16803c', '#157f3b', '#147e3a', '#137d39', '#127c39', '#117b38', '#107a37', '#0e7936', '#0d7836', '#0c7735', '#0b7734', '#0a7633', '#097532', '#087432', '#077331', '#067230', '#05712f', '#03702e', '#026f2e', '#016e2d', '#006d2c', '#006c2c', '#006b2b', '#00692a', '#00682a', '#006729', '#006529', '#006428', '#006328', '#006227', '#006027', '#005f26', '#005e26', '#005c25', '#005b25', '#005a24', '#005924', '#005723', '#005622', '#005522', '#005321', '#005221', '#005120', '#005020', '#004e1f', '#004d1f', '#004c1e', '#004a1e', '#00491d', '#00481d', '#00471c', '#00451c', '#00441b'], 'min': -0.31496545190783054, 'max': 0.6683841573016721}
map.addLayer(ROI_NDVI2, vis_params,"ROI_NDVI2")
map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(bottom=236355.0, center=[17.628954550408725, 73.42307354048903], controls=(WidgetControl(options=['positio…

# %%
CD = ROI_NDVI.subtract(ROI_NDVI2).rename("CD")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
cd_params = {'bands': ['CD'], 'palette': ['#f7fcf5', '#f6fcf4', '#f6fcf4', '#f5fbf3', '#f5fbf2', '#f4fbf2', '#f4fbf1', '#f3faf0', '#f2faf0', '#f2faef', '#f1faee', '#f1faee', '#f0f9ed', '#f0f9ec', '#eff9ec', '#eff9eb', '#eef8ea', '#edf8ea', '#edf8e9', '#ecf8e8', '#ecf8e8', '#ebf7e7', '#ebf7e7', '#eaf7e6', '#e9f7e5', '#e9f7e5', '#e8f6e4', '#e8f6e3', '#e7f6e3', '#e7f6e2', '#e6f5e1', '#e5f5e1', '#e5f5e0', '#e4f5df', '#e3f4de', '#e2f4dd', '#e1f3dc', '#e0f3db', '#dff3da', '#def2d9', '#ddf2d8', '#dcf2d7', '#dbf1d6', '#dbf1d5', '#daf0d4', '#d9f0d3', '#d8f0d2', '#d7efd1', '#d6efd0', '#d5efcf', '#d4eece', '#d3eecd', '#d2edcc', '#d1edcb', '#d0edca', '#cfecc9', '#ceecc8', '#cdecc7', '#ccebc6', '#cbebc5', '#cbeac4', '#caeac3', '#c9eac2', '#c8e9c1', '#c7e9c0', '#c6e8bf', '#c4e8bd', '#c3e7bc', '#c2e7bb', '#c1e6ba', '#c0e6b9', '#bee5b8', '#bde5b6', '#bce4b5', '#bbe4b4', '#bae3b3', '#b8e3b2', '#b7e2b1', '#b6e2af', '#b5e1ae', '#b4e1ad', '#b2e0ac', '#b1e0ab', '#b0dfaa', '#afdfa8', '#aedea7', '#acdea6', '#abdda5', '#aadda4', '#a9dca3', '#a8dca2', '#a7dba0', '#a5db9f', '#a4da9e', '#a3da9d', '#a2d99c', '#a0d99b', '#9fd899', '#9ed798', '#9cd797', '#9bd696', '#99d595', '#98d594', '#97d492', '#95d391', '#94d390', '#92d28f', '#91d28e', '#90d18d', '#8ed08b', '#8dd08a', '#8bcf89', '#8ace88', '#88ce87', '#87cd86', '#86cc85', '#84cc83', '#83cb82', '#81ca81', '#80ca80', '#7fc97f', '#7dc87e', '#7cc87c', '#7ac77b', '#79c67a', '#78c679', '#76c578', '#75c477', '#73c476', '#72c375', '#70c274', '#6ec173', '#6dc072', '#6bc072', '#6abf71', '#68be70', '#66bd6f', '#65bd6f', '#63bc6e', '#62bb6d', '#60ba6c', '#5eb96b', '#5db96b', '#5bb86a', '#5ab769', '#58b668', '#56b567', '#55b567', '#53b466', '#52b365', '#50b264', '#4eb264', '#4db163', '#4bb062', '#4aaf61', '#48ae60', '#46ae60', '#45ad5f', '#43ac5e', '#42ab5d', '#40aa5d', '#3fa95c', '#3fa85b', '#3ea75a', '#3da65a', '#3ca559', '#3ba458', '#3aa357', '#39a257', '#38a156', '#37a055', '#369f54', '#359e53', '#349d53', '#339c52', '#329b51', '#319a50', '#309950', '#2f984f', '#2f974e', '#2e964d', '#2d954d', '#2c944c', '#2b934b', '#2a924a', '#29914a', '#289049', '#278f48', '#268e47', '#258d47', '#248c46', '#238b45', '#228a44', '#218944', '#208843', '#1f8742', '#1e8741', '#1d8640', '#1c8540', '#1a843f', '#19833e', '#18823d', '#17813d', '#16803c', '#157f3b', '#147e3a', '#137d39', '#127c39', '#117b38', '#107a37', '#0e7936', '#0d7836', '#0c7735', '#0b7734', '#0a7633', '#097532', '#087432', '#077331', '#067230', '#05712f', '#03702e', '#026f2e', '#016e2d', '#006d2c', '#006c2c', '#006b2b', '#00692a', '#00682a', '#006729', '#006529', '#006428', '#006328', '#006227', '#006027', '#005f26', '#005e26', '#005c25', '#005b25', '#005a24', '#005924', '#005723', '#005622', '#005522', '#005321', '#005221', '#005120', '#005020', '#004e1f', '#004d1f', '#004c1e', '#004a1e', '#00491d', '#00481d', '#00471c', '#00451c', '#00441b'], 'min': -0.31496545190783054, 'max': 0.6683841573016721}
map.addLayer(CD,cd_params, "CD")
map.centerObject(TALUKA, 11)
map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(bottom=236355.0, center=[17.628954550408725, 73.42307354048903], controls=(WidgetControl(options=['positio…

# %%
region = TALUKA.geometry()

geemap.ee_export_image(
    ROI_NDVI,
    filename='NDVI_2025.tif',
    scale=30,
    region=region
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/bhakti-ee/thumbnails/6791b55680dc93720e9b39fca0fa6469-2d7c71f0ee9b4a1930d9b96780066299:getPixels
# Please wait ...
# Data downloaded to /content/NDVI_2025.tif

# %%
region = TALUKA.geometry()

geemap.ee_export_image(
    ROI_SAVI,
    filename='SAVI_2025.tif',
    scale=60,
    region=region
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/bhakti-ee/thumbnails/9d2200fd0a9c99b9d3eb4ef871026448-734376c8b952d9e904b01a325478ffef:getPixels
# Please wait ...
# Data downloaded to /content/SAVI_2025.tif

# %%
region = TALUKA.geometry()

geemap.ee_export_image(
    ROI_NDWI,
    filename='NDWI_2025.tif',
    scale=30,
    region=region
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/bhakti-ee/thumbnails/363c4f7502fa3c6c8f0430fb1d611ce4-eaa08974e82b66ef7bd6833ae58d6c6b:getPixels
# Please wait ...
# Data downloaded to /content/NDWI_2025.tif

# %%
region = TALUKA.geometry()

geemap.ee_export_image(
    ROI_NDMI,
    filename='NDMI_2025.tif',
    scale=30,
    region= region
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/bhakti-ee/thumbnails/456d892a5f12669e369ca3c98a9a7ac2-586b4f57d05cb8f26703550887b610fd:getPixels
# Please wait ...
# Data downloaded to /content/NDMI_2025.tif

# %%
region = TALUKA.geometry()

geemap.ee_export_image(
    ROI_NDBI,
    filename='NDBI_2025.tif',
    scale=30,
    region= region
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/bhakti-ee/thumbnails/dcd4b5d6ad81c154a2ce2092df9c01c3-f11fa8dcbe3bc8d165d17e91173ef06b:getPixels
# Please wait ...
# Data downloaded to /content/NDBI_2025.tif
